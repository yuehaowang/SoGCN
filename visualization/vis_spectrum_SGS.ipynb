# %%
import os
import json
import dgl
import random
import torch
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from matplotlib import rcParams
import seaborn as sns
sns.set_theme(style="darkgrid")
rcParams['figure.dpi'] = 300

# %%
# !!! make sure only run this cell once

os.chdir('../')

# %%
# %load_ext autoreload
# %autoreload 1

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)

# %%
# %aimport utils.result
# %aimport utils.vis

from utils.result import load_model
from utils.vis import plot_spectrum, TestDataset, IntermediateRecorder

# %% [markdown]
# # Setup CUDA

# %%
device = torch.device("cuda")
torch.cuda.set_device(1)

device
# Out:
# device(type='cuda')

# %% [markdown]
# # Utilities

# %%
def set_seed(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if device.type == 'cuda':
        torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

# %%
def run_model(model, recorder, G, x0, e0):
    with torch.no_grad():
        x0 = x0.float()
        final_out = model(G, x0, e0, recorder)
        return final_out

# %% [markdown]
# # Load Models

# %%
model_paths = ['./_out/SGS_node_regression/bandpass_gcn', './_out/SGS_node_regression/bandpass_gin', './_out/SGS_node_regression/bandpass_sogcn']

model_ls = [load_model(pth, device) for pth in model_paths]

print('Models:')
model_ls
# Out:
# Experiment details:
# Dataset = SGS_BAND_PASS
# Model Type = GCN , Model Name = bandpass_gcn
# Seed = 41
# Best ckpt = GCN_SGS_BAND_PASS_GPU0_06h39m32s_on_Sep_19_2020
# Net params = {'L': 16, 'hidden_dim': 16, 'out_dim': 1, 'residual': True, 'readout': 'sum', 'in_feat_dropout': 0.0, 'dropout': 0.0, 'batch_norm': True, 'self_loop': False, 'gru': False, 'activation': 'identity', 'gpu_id': 0, 'batch_size': 128, 'max_order': 2, 'in_dim': 1, 'total_param': 4611}
# Ckpt path = ./_out/SGS_node_regression/bandpass_gcn/checkpoints/GCN_SGS_BAND_PASS_GPU0_06h39m32s_on_Sep_19_2020/RUN_/epoch_115.pkl
# Restoring ckpt...
# Ckpt restored.
#
# Experiment details:
# Dataset = SGS_BAND_PASS
# Model Type = GIN , Model Name = bandpass_gin
# Seed = 35
# Best ckpt = GIN_SGS_BAND_PASS_GPU2_14h38m59s_on_Feb_04_2021
# Net params = {'L': 16, 'hidden_dim': 16, 'out_dim': 1, 'residual': True, 'readout': 'sum', 'n_mlp_GIN': 1, 'learn_eps_GIN': True, 'neighbor_aggr_GIN': 'sum', 'in_feat_dropout': 0.0, 'dropout': 0.0, 'batch_norm': True, 'activation': 'identity', 'gpu_id': 2, 'batch_size': 128, 'max_order': 2, 'gru': False, 'in_dim': 1, 'total_param': 4627}
# Ckpt path = ./_out/SGS_node_regression/bandpass_gin/checkpoints/GIN_SGS_BAND_PASS_GPU2_14h38m59s_on_Feb_04_2021/RUN_/epoch_197.pkl
# Restoring ckpt...
# Ckpt restored.
#
# Experiment details:
# Dataset = SGS_BAND_PASS
# Model Type = SoGCN , Model Name = bandpass_sogcn
# Seed = 35
# Best ckpt = SoGCN_SGS_BAND_PASS_GPU0_06h13m15s_on_Sep_19_2020
# Net params = {'L': 16, 'hidden_dim': 16, 'out_dim': 1, 'residual': True, 'readout': 'sum', 'in_feat_dropout': 0.0, 'dropout': 0.0, 'batch_norm': True, 'self_loop': False, 'max_order': 2, 'gru': False, 'activation': 'identity', 'gpu_id': 0, 'batch_size': 128, 'in_dim': 1, 'total_param': 12323}
# Ckpt path = ./_out/SGS_node_regression/bandpass_sogcn/checkpoints/SoGCN_SGS_BAND_PASS_GPU0_06h13m15s_on_Sep_19_2020/RUN_/epoch_257.pkl
# Restoring ckpt...
# Ckpt restored.
#
# Models:
# [{'model': GCNNet(
#     (in_feat_dropout): Dropout(p=0.0, inplace=False)
#     (embedding_h): Linear(in_features=1, out_features=16, bias=True)
#     (layers): ModuleList(
#       (0): GCNLayer(in_channels=16, out_channels=16, residual=True, activation=Identity())
#       (1): GCNLayer(in_channels=16, out_channels=16, residual=True, activation=Identity())
#       (2): GCNLayer(in_channels=16, out_channels=16, residual=True, activation=Identity())
#       (3): GCNLayer(in_channels=16, out_channels=16, residual=True, activation=Identity())
#       (4): GCNLayer(in_channels=16, out_channels=16, residual=True, activation=Identity())
#       (5): GCNLayer(in_channels=16, out_channels=16, residual=True, activation=Identity())
#       (6): GCNLayer(in_channels=16, out_channels=16, residual=True, activation=Identity())
#       (7): GCNLayer(in_channels=16, out_channels=16, residual=True, activation=Identity())
#       (8): GCNLayer(in_channels=16, out_channels=16, residual=True, activation=Identity())
#       (9): GCNLayer(in_channels=16, out_channels=16, residual=True, activation=Identity())
#       (10): GCNLayer(in_channels=16, out_channels=16, residual=True, activation=Identity())
#       (11): GCNLayer(in_channels=16, out_channels=16, residual=True, activation=Identity())
#       (12): GCNLayer(in_channels=16, out_channels=16, residual=True, activation=Identity())
#       (13): GCNLayer(in_channels=16, out_channels=16, residual=True, activation=Identity())
#       (14): GCNLayer(in_channels=16, out_channels=16, residual=True, activation=Identity())
#       (15): GCNLayer(in_channels=16, out_channels=1, residual=False, activation=Identity())
#     )
#   ),
#   'dataset': 'SGS_BAND_PASS',
#   'model_name': 'bandpass_gcn',
#   'path': './_out/SGS_node_regression/bandpass_gcn/checkpoints/GCN_SGS_BAND_PASS_GPU0_06h39m32s_on_Sep_19_2020/RUN_/epoch_115.pkl',
#   'seed': 41},
#  {'model': GINNet(
#     (ginlayers): ModuleList(
#       (0): GINLayer(
#         (apply_func): ApplyNodeFunc(
#           (mlp): MLP(
#             (activation): Identity()
#             (linear): Linear(in_features=16, out_features=16, bias=True)
#           )
#         )
#         (activation): Identity()
#         (bn_node_h): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): GINLayer(
#         (apply_func): ApplyNodeFunc(
#           (mlp): MLP(
#             (activation): Identity()
#             (linear): Linear(in_features=16, out_features=16, bias=True)
#           )
#         )
#         (activation): Identity()
#         (bn_node_h): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): GINLayer(
#         (apply_func): ApplyNodeFunc(
#           (mlp): MLP(
#             (activation): Identity()
#             (linear): Linear(in_features=16, out_features=16, bias=True)
#           )
#         )
#         (activation): Identity()
#         (bn_node_h): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (3): GINLayer(
#         (apply_func): ApplyNodeFunc(
#           (mlp): MLP(
#             (activation): Identity()
#             (linear): Linear(in_features=16, out_features=16, bias=True)
#           )
#         )
#         (activation): Identity()
#         (bn_node_h): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (4): GINLayer(
#         (apply_func): ApplyNodeFunc(
#           (mlp): MLP(
#             (activation): Identity()
#             (linear): Linear(in_features=16, out_features=16, bias=True)
#           )
#         )
#         (activation): Identity()
#         (bn_node_h): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (5): GINLayer(
#         (apply_func): ApplyNodeFunc(
#           (mlp): MLP(
#             (activation): Identity()
#             (linear): Linear(in_features=16, out_features=16, bias=True)
#           )
#         )
#         (activation): Identity()
#         (bn_node_h): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (6): GINLayer(
#         (apply_func): ApplyNodeFunc(
#           (mlp): MLP(
#             (activation): Identity()
#             (linear): Linear(in_features=16, out_features=16, bias=True)
#           )
#         )
#         (activation): Identity()
#         (bn_node_h): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (7): GINLayer(
#         (apply_func): ApplyNodeFunc(
#           (mlp): MLP(
#             (activation): Identity()
#             (linear): Linear(in_features=16, out_features=16, bias=True)
#           )
#         )
#         (activation): Identity()
#         (bn_node_h): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (8): GINLayer(
#         (apply_func): ApplyNodeFunc(
#           (mlp): MLP(
#             (activation): Identity()
#             (linear): Linear(in_features=16, out_features=16, bias=True)
#           )
#         )
#         (activation): Identity()
#         (bn_node_h): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (9): GINLayer(
#         (apply_func): ApplyNodeFunc(
#           (mlp): MLP(
#             (activation): Identity()
#             (linear): Linear(in_features=16, out_features=16, bias=True)
#           )
#         )
#         (activation): Identity()
#         (bn_node_h): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (10): GINLayer(
#         (apply_func): ApplyNodeFunc(
#           (mlp): MLP(
#             (activation): Identity()
#             (linear): Linear(in_features=16, out_features=16, bias=True)
#           )
#         )
#         (activation): Identity()
#         (bn_node_h): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (11): GINLayer(
#         (apply_func): ApplyNodeFunc(
#           (mlp): MLP(
#             (activation): Identity()
#             (linear): Linear(in_features=16, out_features=16, bias=True)
#           )
#         )
#         (activation): Identity()
#         (bn_node_h): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (12): GINLayer(
#         (apply_func): ApplyNodeFunc(
#           (mlp): MLP(
#             (activation): Identity()
#             (linear): Linear(in_features=16, out_features=16, bias=True)
#           )
#         )
#         (activation): Identity()
#         (bn_node_h): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (13): GINLayer(
#         (apply_func): ApplyNodeFunc(
#           (mlp): MLP(
#             (activation): Identity()
#             (linear): Linear(in_features=16, out_features=16, bias=True)
#           )
#         )
#         (activation): Identity()
#         (bn_node_h): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (14): GINLayer(
#         (apply_func): ApplyNodeFunc(
#           (mlp): MLP(
#             (activation): Identity()
#             (linear): Linear(in_features=16, out_features=16, bias=True)
#           )
#         )
#         (activation): Identity()
#         (bn_node_h): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (15): GINLayer(
#         (apply_func): ApplyNodeFunc(
#           (mlp): MLP(
#             (activation): Identity()
#             (linear): Linear(in_features=16, out_features=1, bias=True)
#           )
#         )
#         (activation): Identity()
#         (bn_node_h): BatchNorm1d(1, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (embedding_h): Linear(in_features=1, out_features=16, bias=True)
#   ),
#   'dataset': 'SGS_BAND_PASS',
#   'model_name': 'bandpass_gin',
#   'path': './_out/SGS_node_regression/bandpass_gin/checkpoints/GIN_SGS_BAND_PASS_GPU2_14h38m59s_on_Feb_04_2021/RUN_/epoch_197.pkl',
#   'seed': 35},
#  {'model': SoGCNNet(
#     (embedding_h): Linear(in_features=1, out_features=16, bias=True)
#     (in_feat_dropout): Dropout(p=0.0, inplace=False)
#     (layers): ModuleList(
#       (0): SoGCNLayer(in_channels=16, out_channels=16, residual=True, max_order=2, activation=Identity())
#       (1): SoGCNLayer(in_channels=16, out_channels=16, residual=True, max_order=2, activation=Identity())
#       (2): SoGCNLayer(in_channels=16, out_channels=16, residual=True, max_order=2, activation=Identity())
#       (3): SoGCNLayer(in_channels=16, out_channels=16, residual=True, max_order=2, activation=Identity())
#       (4): SoGCNLayer(in_channels=16, out_channels=16, residual=True, max_order=2, activation=Identity())
#       (5): SoGCNLayer(in_channels=16, out_channels=16, residual=True, max_order=2, activation=Identity())
#       (6): SoGCNLayer(in_channels=16, out_channels=16, residual=True, max_order=2, activation=Identity())
#       (7): SoGCNLayer(in_channels=16, out_channels=16, residual=True, max_order=2, activation=Identity())
#       (8): SoGCNLayer(in_channels=16, out_channels=16, residual=True, max_order=2, activation=Identity())
#       (9): SoGCNLayer(in_channels=16, out_channels=16, residual=True, max_order=2, activation=Identity())
#       (10): SoGCNLayer(in_channels=16, out_channels=16, residual=True, max_order=2, activation=Identity())
#       (11): SoGCNLayer(in_channels=16, out_channels=16, residual=True, max_order=2, activation=Identity())
#       (12): SoGCNLayer(in_channels=16, out_channels=16, residual=True, max_order=2, activation=Identity())
#       (13): SoGCNLayer(in_channels=16, out_channels=16, residual=True, max_order=2, activation=Identity())
#       (14): SoGCNLayer(in_channels=16, out_channels=16, residual=True, max_order=2, activation=Identity())
#       (15): SoGCNLayer(in_channels=16, out_channels=1, residual=False, max_order=2, activation=Identity())
#     )
#   ),
#   'dataset': 'SGS_BAND_PASS',
#   'model_name': 'bandpass_sogcn',
#   'path': './_out/SGS_node_regression/bandpass_sogcn/checkpoints/SoGCN_SGS_BAND_PASS_GPU0_06h13m15s_on_Sep_19_2020/RUN_/epoch_257.pkl',
#   'seed': 35}]

# %% [markdown]
# # Prepare Data

# %%
'''
Load data
'''
dataset_name = model_ls[0]['dataset']
dataset = TestDataset(dataset_name, device)
# Out:
# [I] Loading dataset SGS_BAND_PASS...
# max in-degrees, out-degrees: 12 12
# train, test, val sizes : 1000 2000 1000
# [I] Finished loading.
# [I] Data load time: 2.4993s

# %% [markdown]
# # Run Model

# %%
set_seed(41)

# %%
'''
Retrieve data and run model
'''

G, label, X0, E0, U = dataset.pick()

recorder_ls = []

for item in model_ls:
    model = item['model']
    model_name = item['model_name']
    ckpt_path = item['path']
    
    print('%s (%s)' % (model_name, ckpt_path))
    recorder = IntermediateRecorder(model_name)
    f_out = run_model(model, recorder, G, X0, E0)
    print('\tLoss =', model.loss(label.float(), f_out).item())
    
    recorder_ls.append(recorder)
# Out:
# bandpass_gcn (./_out/SGS_node_regression/bandpass_gcn/checkpoints/GCN_SGS_BAND_PASS_GPU0_06h39m32s_on_Sep_19_2020/RUN_/epoch_115.pkl)
# 	Loss = 0.31538236141204834
# bandpass_gin (./_out/SGS_node_regression/bandpass_gin/checkpoints/GIN_SGS_BAND_PASS_GPU2_14h38m59s_on_Feb_04_2021/RUN_/epoch_197.pkl)
# 	Loss = 0.22565047442913055
# bandpass_sogcn (./_out/SGS_node_regression/bandpass_sogcn/checkpoints/SoGCN_SGS_BAND_PASS_GPU0_06h13m15s_on_Sep_19_2020/RUN_/epoch_257.pkl)
# 	Loss = 0.04800686240196228

# %% [markdown]
# # Visualization

# %%
'''
Freq - magnitude plot
'''

title_ls = ['(a) Vanilla GCN', '(b) GIN', '(c) SoGCN']

vis_out_ls = [[rec['input'][0]] + rec['out'] for rec in recorder_ls]
model_name_ls = [rec.target_name for rec in recorder_ls]

vis_layers = [16]
print('vis layers:', vis_layers)

subplots_w = len(vis_out_ls)
subplots_h = len(vis_layers)

plot_w = 15
h_w_ratio = 8 / 7.5

fig, ax = plt.subplots(subplots_h, subplots_w, sharex=True, sharey=True, figsize=(plot_w, subplots_h * h_w_ratio * (plot_w / subplots_w)), constrained_layout=True)
if len(vis_layers) <= 1:
    ax = ax[np.newaxis, ...]
    
for i in range(subplots_w):
    for j in range(subplots_h):
        L = vis_layers[j]
        plot_spectrum((label.float(), U), ax[j, i], None, 'curves', y_label=None, lw=3, label='GT')
        plot_spectrum((vis_out_ls[i][L], U), ax[j, i], None, 'curves', y_label=None, lw=2, label='Predicted')
        ax[j, i].legend(fontsize=15)


for i in range(subplots_w):
    ax[0, i].annotate(title_ls[i],
                xy=(0.5, 1), xytext=(0, 25), xycoords='axes fraction', textcoords='offset points',
                size=20, ha='center', va='baseline')

for j in range(subplots_h):
    ax[j, 0].annotate('Magnitude',
            xy=(0, 0.5), xytext=(-ax[j,0].yaxis.labelpad - 15, 0),
            xycoords=ax[j,0].yaxis.label, textcoords='offset points',
            size=15, ha='right', va='center', rotation=90)

if subplots_h > 1:
    for j in range(subplots_h):
        ax[j, 0].annotate(('L=%s' % vis_layers[j]) if vis_layers[j] != 0 else 'Input',
                    xy=(0, 0.5), xytext=(-ax[j, 0].yaxis.labelpad - 45, 0),
                    xycoords=ax[j, 0].yaxis.label, textcoords='offset points',
                    size=20, ha='right', va='center')

if not os.path.exists('vis_out'):
    os.makedirs('vis_out')
fig.savefig('vis_out/vis_sgs_spectrum.pdf')
# Out:
# vis layers: [16]
